# %% [markdown]
# # 🔀 Exercise 8: The IF Path (Conditionals)
#
# Teach Python to make decisions using **if** statements!
#
# ```python
# if condition:
#     do something
# ```
#
# ---

# %% [markdown]
# ### Example: Are you a Big Kid?

# %%
age = 7
if age >= 6:
    print("You are a BIG KID!")

# %% [markdown]
# ### 🎯 Your Turn!
# Change the `temperature` variable and see what Python decides!

# %%
temperature = 35  # Try changing this number!

if temperature > 30:
    print("It's HOT! ☀️ Drink some water!")
else:
    print("It's nice outside! 🌤️ Go play!")

# %% [markdown]
# ### 🌟 Bonus: Grade Calculator!
# Fill in the missing code to create a grade checker!

# %%
score = 85  # Try different scores!

if score >= 90:
    print("A+ Amazing! 🌟")
elif score >= 80:
    print("B - Great job! 👏")
elif score >= 70:
    print("C - Good effort! 💪")
else:
    print("Keep practicing! You'll get there! 🚀")
