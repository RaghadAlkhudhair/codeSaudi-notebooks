# %% [markdown]
# # 📦 Exercise 2: Naming Things (Variables)
#
# Variables are like labeled boxes that store information!
#
# **Your Mission:** Create variables and print them.
#
# ---

# %% [markdown]
# ### Example: Creating Variables

# %%
# Creating variables is easy!
name = "Super Coder"
age = 7
print(name)
print(age)

# %% [markdown]
# ### 🎯 Your Turn!
# Create a variable called `my_name` with YOUR name, and a variable called `my_age` with your age. Then print both!

# %%
# Create your own variables:
my_name = "___"
my_age = 0

# Print them:
print(my_name)
print(my_age)

# %% [markdown]
# ### 🌟 Bonus Challenge!
# Create a variable for your favorite food and your favorite color, then print a sentence using them!

# %%
# Your bonus code here:
favorite_food = "___"
favorite_color = "___"

print("I love eating " + favorite_food + " and my favorite color is " + favorite_color)
