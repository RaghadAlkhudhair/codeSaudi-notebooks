# %% [markdown]
# # ✨ Exercise 4: Word Play (String Magic)
#
# We can mix words and variables together to make story magic!
#
# Use the `+` sign to glue strings together.
#
# ---

# %% [markdown]
# ### Example: Combining Words

# %%
hero = "Robo"
print("Once upon a time, " + hero + " saved the day!")

# %% [markdown]
# ### 🎯 Your Turn!
# Create a `hero` variable with YOUR name and write a short story!

# %%
hero = "___"
villain = "___"
power = "___"

# Create your story:
print(hero + " used " + power + " to defeat " + villain + "!")

# %% [markdown]
# ### 🌟 Bonus: Mad Libs Game!
# Fill in the blanks to make a funny story!

# %%
animal = "___"
food = "___"
place = "___"
number = "___"

print("One day, a " + animal + " ate " + number + " plates of " + food + " at the " + place + "!")
print("Everyone was so surprised, they gave the " + animal + " a golden trophy! 🏆")
