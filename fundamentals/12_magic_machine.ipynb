# %% [markdown]
# # ⚙️ Exercise 12: The Magic Machine (Functions)
#
# A **function** is like a magic machine — you build it once, and use it whenever you want!
#
# ```python
# def my_function():
#     # code goes here
# ```
#
# ---

# %% [markdown]
# ### Example: The Super Jump Machine

# %%
def super_jump():
    print("Jumping high! 💨")

# Use your machine:
super_jump()
super_jump()
super_jump()

# %% [markdown]
# ### 🎯 Your Turn!
# Create a function called `say_hello` that prints a greeting, then call it 3 times!

# %%
# Build your machine:
def say_hello():
    print("Hello! 👋 Nice to meet you!")

# Use it 3 times:
say_hello()
say_hello()
say_hello()

# %% [markdown]
# ### 🌟 Bonus: Functions with Input!
# Make a machine that takes a name and greets that person!

# %%
def greet(name):
    print("Welcome, " + name + "! You are awesome! 🌟")

# Greet different people:
greet("Ali")
greet("Sara")
greet("Robo")

# Try adding your own name below:
# greet("Your Name")
