# %% [markdown]
# # 🚀 Exercise 11: The WHILE Wait (While Loops)
#
# A `while` loop keeps going **until** a condition becomes False!
#
# ```python
# while condition:
#     do something
# ```
#
# ⚠️ **Warning:** Make sure the condition eventually becomes False, or the loop will run forever!
#
# ---

# %% [markdown]
# ### Example: Countdown to Blast Off!

# %%
countdown = 3
while countdown > 0:
    print(countdown)
    countdown = countdown - 1
print("BLAST OFF! 🚀")

# %% [markdown]
# ### 🎯 Your Turn!
# Change the countdown to start from 10!

# %%
# Change the starting number:
countdown = 10  # Start from 10!

while countdown > 0:
    print(countdown, "...")
    countdown = countdown - 1

print("💥 BLAST OFF! 🚀")

# %% [markdown]
# ### 🌟 Bonus: The Cookie Jar!
# Keep eating cookies until the jar is empty!

# %%
cookies = 5

while cookies > 0:
    print("Yum! 🍪 Eating a cookie... (" + str(cookies) + " left)")
    cookies = cookies - 1

print("The cookie jar is EMPTY! 😢")
print("Time to bake more! 👨‍🍳")
