# %% [markdown]
# # 🧠 Exercise 9: And, Or, Not (Logic)
#
# Combine multiple conditions together!
#
# - `and` — BOTH must be True
# - `or` — At least ONE must be True
# - `not` — Flips True to False!
#
# ---

# %% [markdown]
# ### Example: Park Day Decision

# %%
is_sunny = True
has_ball = True

if is_sunny and has_ball:
    print("Go to the park! ⚽")
else:
    print("Stay home and read 📚")

# %% [markdown]
# ### 🎯 Your Turn!
# Change `is_sunny` and `has_ball` to `False` and see what happens!

# %%
# Try changing these to True or False:
is_weekend = True
homework_done = False

if is_weekend and homework_done:
    print("You can play video games! 🎮")
elif is_weekend and not homework_done:
    print("Do homework first, then play! 📝")
else:
    print("It's a school day! 🏫")

# %% [markdown]
# ### 🌟 Bonus: The Superhero Checker!
# Can you fly AND have super strength? Only then are you a TRUE superhero!

# %%
can_fly = True
has_strength = True
has_cape = False

if can_fly and has_strength:
    print("You're a SUPERHERO! 🦸")
elif can_fly or has_strength:
    print("You have ONE power! Almost there! 💪")
else:
    print("Keep training! Every hero starts somewhere! 🏋️")

if not has_cape:
    print("But you need a cape! 🦸‍♂️")
