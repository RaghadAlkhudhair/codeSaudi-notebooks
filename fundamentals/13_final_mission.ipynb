# %% [markdown]
# # 🏆 Final Mission: Prove You're a Python Master!
#
# This is your FINAL challenge! Use everything you've learned:
# - Variables, Strings, Numbers
# - If/Else, And/Or
# - For Loops, While Loops
# - Functions
#
# Complete all 3 challenges to earn your **Python Master Badge**! 👑
#
# ---

# %% [markdown]
# ## Challenge 1: Introduce Yourself!
# Print your name and count from 1 to 10.

# %%
# Challenge 1: Your introduction
name = "___"  # Put your name here!
print("Hi! My name is " + name + "!")

# Count from 1 to 10:
for i in range(1, 11):
    print(i)

# %% [markdown]
# ## Challenge 2: The Number Guessing Game!
# The computer picks a secret number. Can you guess it?

# %%
import random

secret = random.randint(1, 10)
guess = 0
tries = 0

while guess != secret:
    guess = int(input("Guess a number between 1 and 10: "))
    tries = tries + 1
    
    if guess < secret:
        print("Too LOW! Try higher! ⬆️")
    elif guess > secret:
        print("Too HIGH! Try lower! ⬇️")
    else:
        print("🎉 CORRECT! You got it in " + str(tries) + " tries!")

# %% [markdown]
# ## Challenge 3: Build Your Own Greeting Machine!
# Create a function that takes a name and a number, then greets that person that many times!

# %%
# Build your greeting machine:
def mega_greet(name, times):
    for i in range(times):
        print("Hello " + name + "! (" + str(i + 1) + "/" + str(times) + ") 🎉")
    print("---")

# Test it:
mega_greet("Ali", 3)
mega_greet("Sara", 2)

# Now try YOUR name:
# mega_greet("Your Name", 5)

# %% [markdown]
# ---
#
# # 🎊 CONGRATULATIONS! 🎊
#
# You completed ALL the Python challenges!
#
# **You are now a certified Python Coder!** 🐍👑
#
# Keep coding, keep creating, and never stop learning!
#
# — Robo 🤖❤️
