# %% [markdown]
# # 🐍 Exercise 1: Hello Python!
#
# Welcome to your first Python exercise! In this notebook, you'll learn to use the `print()` command.
#
# **Your Mission:** Make the computer say "Hello World!"
#
# ---

# %% [markdown]
# ### Example: Run this cell by clicking the ▶ Play button!

# %%
# This is the print command - it shows text on the screen!
print("Hello World!")

# %% [markdown]
# ### 🎯 Your Turn!
# Change the message inside `print()` to say YOUR name!

# %%
# Type your code below:
print("My name is ___")

# %% [markdown]
# ### 🌟 Bonus Challenge!
# Can you print THREE different messages? One on each line?

# %%
# Print 3 messages:
print("Message 1")
# Add two more print statements below:
